# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from other import routing_one_ambulance, routing_for_4

df = pd.read_csv("sample1.csv")
number_of_hospital = 5

kmeans = KMeans(n_clusters= number_of_hospital)
kmeans.fit(df[['x', 'y']])
#df['cluster'] = kmeans.predict(df[['x', 'y']]).tolist()
x = df["x"]
y = df["y"]
Cluster = kmeans.labels_
#scatter = ax.scatter(x,y,c=Cluster,s=50)
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(x,y,c=Cluster,s=50)
ax.set_xlabel('x')
ax.set_ylabel('y')
centers = kmeans.cluster_centers_
for i,j in centers:
    ax.scatter(i,j,s=50,c='red',marker='+')
plt.colorbar(scatter)

fig.show()

# %%
df = pd.read_csv("sample2.csv")
def plot_cluster(df, number_cluster):

    kmeans = KMeans(n_clusters= number_cluster)
    kmeans.fit(df[['x', 'y']])
    x = df["x"]
    y = df["y"]
    Cluster = kmeans.labels_
    fig = plt.figure()
    ax = fig.add_subplot(111)
    scatter = ax.scatter(x,y,c=Cluster,s=50)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    centers = kmeans.cluster_centers_
    for i,j in centers:
        ax.scatter(i,j,s=50,c='red',marker='+')
    plt.colorbar(scatter)

    fig.show()
    df["cluster"] = kmeans.labels_
    return df
plot_cluster(df, 5)
# Out:
#        x   y  time_to_live  cluster
# 0     68  28           115        4
# 1     16  77            94        0
# 2     32  69           144        0
# 3     66   5           115        4
# 4    100  72           129        1
# ..   ...  ..           ...      ...
# 293   69  68            99        1
# 294   62  34            71        4
# 295   26  43            89        3
# 296   41  96           143        0
# 297   11  86            82        0
#
# [298 rows x 4 columns]

# %%
df = pd.read_csv("sample1.csv")
number_of_hospital = 5
num_ambulance_at_hospital = [6, 5, 5, 3, 3]

kmeans = KMeans(n_clusters= number_of_hospital)
kmeans.fit(df[['x', 'y']])
df["cluster"] = kmeans.labels_
cluster_locations = kmeans.cluster_centers_

# %%
import heapq
from collections import Counter, defaultdict
heap = []
for i, count in enumerate(num_ambulance_at_hospital):
    heap.append((-count, i))
heapq.heapify(heap)

print(heap)

cluster_map = {}
counter = Counter(kmeans.labels_)
print(counter)

for i, (elem, count) in enumerate(counter.most_common()):
    count, hospital_idx = heapq.heappop(heap)
    print(-count, hospital_idx)
    cluster_map[elem] = hospital_idx

print(cluster_map)

hospital_number = []
for cluster_num in kmeans.labels_:
    hospital_idx = cluster_map[cluster_num]
    hospital_number.append(hospital_idx)
df["hospital_number"] = hospital_number
# Out:
# [(-6, 0), (-5, 1), (-5, 2), (-3, 3), (-3, 4)]
# Counter({1: 12, 0: 10, 2: 10, 4: 9, 3: 9})
# 6 0
# 5 1
# 5 2
# 3 3
# 3 4
# {1: 0, 0: 1, 2: 2, 4: 3, 3: 4}

# %%
patients_picked = []
am_number = 0
total_patients_picked = 0
for cluster_num in range(number_of_hospital):

    hospital_number = cluster_map[cluster_num]

    df_hospital = df.loc[df['hospital_number'] == hospital_number]
    hospital_location = cluster_locations[cluster_num]
    hospital_total_ambulance = num_ambulance_at_hospital[hospital_number]

    df_hospital = plot_cluster(df_hospital, hospital_total_ambulance)

    df_hospital["time_to_hospital"] = abs(df_hospital["x"] - hospital_location[0]) + abs(df_hospital["y"]-hospital_location[1])
    
    for ambulance_no in range(hospital_total_ambulance):
        df_ambulance = df_hospital.loc[df_hospital['cluster'] == ambulance_no]
        df_ambulance["index"] = df_ambulance.index
        print("printing for the ambulance", am_number)
        
        df_ambulance.to_csv(str(am_number) + ".csv", index = False)
        print(routing_one_ambulance(df_ambulance))
        num, patient_per_ambulance = routing_one_ambulance(df_ambulance)
        patients_picked.append(patient_per_ambulance)
        print(num)
        total_patients_picked = total_patients_picked + num
        am_number = am_number + 1
# Out:
# printing for the ambulance 0
#    index   x   y  time_to_live  time_to_hospital
# 0      0  38  77            21              25.6
# 1     33  24  65            56              23.6
# 2      8  39  77            58              26.6
# (1, [[33.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0      0  38  77            21              25.6
# 1     33  24  65            56              23.6
# 2      8  39  77            58              26.6
# 1
# printing for the ambulance 1
#    index  x   y  time_to_live  time_to_hospital
# 0     15  5  92            50              22.4
# 1     12  1  89            53              23.4
# (1, [[15.0]])
#    index  x   y  time_to_live  time_to_hospital
# 0     15  5  92            50              22.4
# 1     12  1  89            53              23.4
# 1
# printing for the ambulance 2
#    index   x   y  time_to_live  time_to_hospital
# 0     22  22  86            80               5.0
# 1     14  18  83            95               2.0
# (2, [[22.0, 14.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     22  22  86            80               5.0
# 1     14  18  83            95               2.0
# 2
# printing for the ambulance 3
#    index  x   y  time_to_live  time_to_hospital
# 0     35  3  69           102              31.0
# (1, [[35.0]])
#    index  x   y  time_to_live  time_to_hospital
# 0     35  3  69           102              31.0
# 1
# printing for the ambulance 4
#    index   x    y  time_to_live  time_to_hospital
# 0     26  17  100            25              18.4
# 1      6  25  100            58              22.0
# (1, [[6.0]])
#    index   x    y  time_to_live  time_to_hospital
# 0     26  17  100            25              18.4
# 1      6  25  100            58              22.0
# 1
# printing for the ambulance 5
#    index  x   y  time_to_live  time_to_hospital
# 0     47  7  20            20              28.5
# 1     37  2  26            87              27.5
# (1, [[37.0]])
#    index  x   y  time_to_live  time_to_hospital
# 0     47  7  20            20              28.5
# 1     37  2  26            87              27.5
# 1
# printing for the ambulance 6
#    index   x   y  time_to_live  time_to_hospital
# 0     45  25  53            34              22.5
# 1     42  30  50            73              24.5
# (1, [[42.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     45  25  53            34              22.5
# 1     42  30  50            73              24.5
# 1
# printing for the ambulance 7
#    index   x  y  time_to_live  time_to_hospital
# 0     17  18  1            71              36.5
# 1      3  15  7            78              33.5
# (1, [[3.0]])
#    index   x  y  time_to_live  time_to_hospital
# 0     17  18  1            71              36.5
# 1      3  15  7            78              33.5
# 1
# printing for the ambulance 8
#    index   x   y  time_to_live  time_to_hospital
# 0      1  17  23            29              15.5
# 1      2  17  20           102              18.5
# (1, [[2.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0      1  17  23            29              15.5
# 1      2  17  20           102              18.5
# 1
# printing for the ambulance 9
#    index   x   y  time_to_live  time_to_hospital
# 0     41  29  42            67              15.5
# 1     38  38  41            69              23.5
# (2, [[41.0, 38.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     41  29  42            67              15.5
# 1     38  38  41            69              23.5
# 2
# printing for the ambulance 10
#    index   x   y  time_to_live  time_to_hospital
# 0     27  35  57            39              36.5
# 1     44  36  57            55              37.5
# (0, [[]])
#    index   x   y  time_to_live  time_to_hospital
# 0     27  35  57            39              36.5
# 1     44  36  57            55              37.5
# 0
# printing for the ambulance 11
#    index   x   y  time_to_live  time_to_hospital
# 0     24  82  67            56              17.6
# (1, [[24.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     24  82  67            56              17.6
# 1
# printing for the ambulance 12
#    index   x   y  time_to_live  time_to_hospital
# 0      7  68  57            52               6.4
# 1     13  66  47            58              18.4
# 2     46  58  41            85              32.4
# 3     19  62  50           112              19.4
# (3, [[7.0, 13.0, 19.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0      7  68  57            52               6.4
# 1     13  66  47            58              18.4
# 2     46  58  41            85              32.4
# 3     19  62  50           112              19.4
# 3
# printing for the ambulance 13
#    index   x   y  time_to_live  time_to_hospital
# 0     32  69  72            37              19.2
# 1     18  64  75            47              27.2
# (0, [[]])
#    index   x   y  time_to_live  time_to_hospital
# 0     32  69  72            37              19.2
# 1     18  64  75            47              27.2
# 0
# printing for the ambulance 14
#    index   x   y  time_to_live  time_to_hospital
# 0     43  82  55            74              10.8
# 1     20  87  50           101              20.8
# (2, [[43.0, 20.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     43  82  55            74              10.8
# 1     20  87  50           101              20.8
# 2
# printing for the ambulance 15
#    index    x   y  time_to_live  time_to_hospital
# 0     36  100  62           106              30.6
# (1, [[36.0]])
#    index    x   y  time_to_live  time_to_hospital
# 0     36  100  62           106              30.6
# 1
# printing for the ambulance 16
#    index   x   y  time_to_live  time_to_hospital
# 0     48  98  88            51         21.888889
# 1     31  99  83            76         27.888889
# (1, [[48.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     48  98  88            51         21.888889
# 1     31  99  83            76         27.888889
# 1
# printing for the ambulance 17
#    index   x    y  time_to_live  time_to_hospital
# 0     25  65   92            27         18.444444
# 1     28  69  100            59         19.111111
# 2     40  54   93            60         28.444444
# 3      9  58   95           108         25.111111
# (2, [[28.0], [9.0]])
#    index   x    y  time_to_live  time_to_hospital
# 0     25  65   92            27         18.444444
# 1     28  69  100            59         19.111111
# 2     40  54   93            60         28.444444
# 3      9  58   95           108         25.111111
# 2
# printing for the ambulance 18
#    index   x    y  time_to_live  time_to_hospital
# 0     21  99  100            24         23.555556
# 1     29  99   93            37         17.888889
# 2     34  95   99            99         18.555556
# (1, [[34.0]])
#    index   x    y  time_to_live  time_to_hospital
# 0     21  99  100            24         23.555556
# 1     29  99   93            37         17.888889
# 2     34  95   99            99         18.555556
# 1
# printing for the ambulance 19
#    index   x   y  time_to_live  time_to_hospital
# 0     16  71   3            53         15.444444
# 1     11  75   1            72         17.444444
# 2     39  74  11            96          6.444444
# 3     30  86   9           116         20.444444
# (4, [[16.0, 11.0, 39.0], [30.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     16  71   3            53         15.444444
# 1     11  75   1            72         17.444444
# 2     39  74  11            96          6.444444
# 3     30  86   9           116         20.444444
# 4
# printing for the ambulance 20
#    index   x   y  time_to_live  time_to_hospital
# 0     49  89  27            29         26.555556
# 1      4  84  26            95         20.555556
# (1, [[4.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0     49  89  27            29         26.555556
# 1      4  84  26            95         20.555556
# 1
# printing for the ambulance 21
#    index   x   y  time_to_live  time_to_hospital
# 0      5  64  30            74         22.555556
# 1     10  56  26            80         26.555556
# 2     23  58  15            87         16.444444
# (3, [[5.0, 10.0, 23.0]])
#    index   x   y  time_to_live  time_to_hospital
# 0      5  64  30            74         22.555556
# 1     10  56  26            80         26.555556
# 2     23  58  15            87         16.444444
# 3

# %%
patients_picked
# Out:
# [[[33.0]],
#  [[15.0]],
#  [[22.0, 14.0]],
#  [[35.0]],
#  [[6.0]],
#  [[37.0]],
#  [[42.0]],
#  [[3.0]],
#  [[2.0]],
#  [[41.0, 38.0]],
#  [[]],
#  [[24.0]],
#  [[7.0, 13.0, 19.0]],
#  [[]],
#  [[43.0, 20.0]],
#  [[36.0]],
#  [[48.0]],
#  [[28.0], [9.0]],
#  [[34.0]],
#  [[16.0, 11.0, 39.0], [30.0]],
#  [[4.0]],
#  [[5.0, 10.0, 23.0]]]

# %%
total_patients_picked
# Out:
# 31

# %%
patients_picked
# Out:
# [[[82.0, 218.0], [21.0, 2.0], [230.0]],
#  [[185.0, 238.0, 31.0], [159.0, 1.0], [134.0, 260.0]],
#  [[127.0, 246.0, 126.0, 53.0], [277.0, 88.0, 34.0]],
#  [[281.0, 235.0]],
#  [[62.0, 60.0, 10.0, 112.0], [108.0, 172.0], [213.0]],
#  [[28.0, 259.0, 78.0, 176.0]],
#  [[99.0, 171.0, 152.0], [94.0], [163.0, 193.0, 211.0], [45.0]],
#  [[204.0, 217.0], [90.0], [169.0]],
#  [[229.0, 84.0, 195.0, 282.0], [158.0, 182.0]],
#  [[136.0, 7.0], [66.0]],
#  [[75.0, 294.0, 19.0, 237.0], [145.0, 168.0], [102.0]],
#  [[243.0, 251.0, 276.0, 154.0], [8.0, 290.0, 153.0], [177.0], [173.0, 29.0]],
#  [[248.0], [104.0, 137.0]],
#  [[114.0, 165.0, 175.0]],
#  [[85.0, 266.0, 27.0, 167.0], [20.0]],
#  [[174.0, 209.0], [111.0, 216.0]],
#  [[155.0, 12.0, 106.0, 268.0], [221.0, 224.0, 160.0]],
#  [[25.0, 199.0, 288.0], [115.0, 261.0]],
#  [[16.0, 227.0, 14.0, 147.0], [71.0]],
#  [[181.0, 244.0, 289.0, 272.0], [6.0, 190.0]],
#  [[37.0, 32.0, 242.0], [161.0, 150.0, 240.0]],
#  [[283.0, 273.0, 107.0, 270.0], [11.0, 236.0, 187.0, 141.0], [183.0]]]

# %%
am_number
# Out:
# 22
